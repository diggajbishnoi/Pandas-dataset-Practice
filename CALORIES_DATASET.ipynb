# %% [markdown]
# ## 1st DATASET PRACTICE:-  Calories Dataset

# %%
## To load the csv file:-
import pandas as pd
df = pd.read_csv('data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
## To print the entire DataFrame we use :- to_string() attribute.
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
## To print the number of non empty cells for each columns/row:-  [use count()]
print(df.count())
# Out:
# Duration    169
# Pulse       169
# Maxpulse    169
# Calories    164
# dtype: int64

# %%
##To return the header row and & first 10 rows or specified rows:- use head()
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
## To return the header and the last rows:- use tail() attribute.
print(df.tail(10))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
## To return the not null values:- notnull() attribute
print(df.notnull())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        True   True      True      True
# 1        True   True      True      True
# 2        True   True      True      True
# 3        True   True      True      True
# 4        True   True      True      True
# ..        ...    ...       ...       ...
# 164      True   True      True      True
# 165      True   True      True      True
# 166      True   True      True      True
# 167      True   True      True      True
# 168      True   True      True      True
#
# [169 rows x 4 columns]

# %%
## To check the dataset has null values:- isnull() attribute
print(df.isnull())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
df[['Calories','Pulse']]
# Out:
#      Calories  Pulse
# 0       409.1    110
# 1       479.0    117
# 2       340.0    103
# 3       282.4    109
# 4       406.0    117
# ..        ...    ...
# 164     290.8    105
# 165     300.0    110
# 166     310.2    115
# 167     320.4    120
# 168     330.4    125
#
# [169 rows x 2 columns]

# %%
df['Maxpulse']
# Out:
# 0      130
# 1      145
# 2      135
# 3      175
# 4      148
#       ...
# 164    140
# 165    145
# 166    145
# 167    150
# 168    150
# Name: Maxpulse, Length: 169, dtype: int64

# %%
## To retur the description summary for each column in data frame:- describe()
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df[['Pulse','Calories']]
# Out:
#      Pulse  Calories
# 0      110     409.1
# 1      117     479.0
# 2      103     340.0
# 3      109     282.4
# 4      117     406.0
# ..     ...       ...
# 164    105     290.8
# 165    110     300.0
# 166    115     310.2
# 167    120     320.4
# 168    125     330.4
#
# [169 rows x 2 columns]

# %%
## allow the grouping of data and perform functions on these groups:- use  groupby('')['']. function name()
df.groupby('Pulse')['Calories'].count()
# Out:
# Pulse
# 80      2
# 83      1
# 85      1
# 90     11
# 92      3
# 93      3
# 95      3
# 97      6
# 98      6
# 99      2
# 100    19
# 101     2
# 102     6
# 103     8
# 104     4
# 105     5
# 106     6
# 107     7
# 108     7
# 109     9
# 110     7
# 111     6
# 112     2
# 113     1
# 114     4
# 115     3
# 116     1
# 117     3
# 118     3
# 119     1
# 120     1
# 121     1
# 122     1
# 123     2
# 124     1
# 125     1
# 129     1
# 130     1
# 136     3
# 137     1
# 141     1
# 149     1
# 150     2
# 151     2
# 152     1
# 153     1
# 159     1
# Name: Calories, dtype: int64

# %%
df.groupby('Pulse')['Calories'].mean()
# Out:
# Pulse
# 80      145.700000
# 83       50.300000
# 85      250.400000
# 90      401.227273
# 92      192.233333
# 93      317.033333
# 95      158.633333
# 97      522.383333
# 98      313.233333
# 99      369.700000
# 100     424.978947
# 101     449.550000
# 102     312.333333
# 103     291.887500
# 104     310.275000
# 105     397.840000
# 106     276.666667
# 107     419.228571
# 108     663.957143
# 109     378.122222
# 110     422.614286
# 111     371.933333
# 112     277.900000
# 113     308.000000
# 114     371.450000
# 115     311.066667
# 116     443.000000
# 117     400.900000
# 118     413.333333
# 119     336.700000
# 120     320.400000
# 121     450.700000
# 122     335.400000
# 123     482.050000
# 124     124.200000
# 125     330.400000
# 129     242.000000
# 130     300.000000
# 136     299.066667
# 137    1860.400000
# 141     222.400000
# 149     344.000000
# 150     201.600000
# 151     264.700000
# 152     244.200000
# 153     226.400000
# 159     319.200000
# ...

# %%
df.groupby('Pulse')['Calories'].median()
# Out:
# Pulse
# 80      145.70
# 83       50.30
# 85      250.40
# 90      500.00
# 92      241.00
# 93      223.00
# 95      128.20
# 97      276.35
# 98      273.00
# 99      369.70
# 100     282.00
# 101     449.55
# 102     312.60
# 103     331.00
# 104     304.25
# 105     290.80
# 106     299.15
# 107     361.00
# 108     367.60
# 109     374.00
# 110     374.00
# 111     382.75
# 112     277.90
# 113     308.00
# 114     383.40
# 115     310.20
# 116     443.00
# 117     406.00
# 118     413.00
# 119     336.70
# 120     320.40
# 121     450.70
# 122     335.40
# 123     482.05
# 124     124.20
# 125     330.40
# 129     242.00
# 130     300.00
# 136     238.00
# 137    1860.40
# 141     222.40
# 149     344.00
# 150     201.60
# 151     264.70
# 152     244.20
# 153     226.40
# 159     319.20
# Name: Calories, dtype: float64

# %%
df.groupby('Maxpulse')['Pulse'].sum()
# Out:
# Maxpulse
# 100     260
# 101     130
# 103     129
# 107     173
# 108      92
# 110      90
# 112     365
# 113      93
# 115      92
# 118      92
# 119     199
# 120    1533
# 121     118
# 122     295
# 123     201
# 124     701
# 125     399
# 126     306
# 127     918
# 128     399
# 129     520
# 130     908
# 131     633
# 132     518
# 133     212
# 134     419
# 135     425
# 136     853
# 137     444
# 138     440
# 139     338
# 140     319
# 141     344
# 143     225
# 144     115
# 145     342
# 146     470
# 147     103
# 148     117
# 149     122
# 150     469
# 151     562
# 152     123
# 153     218
# 156     136
# 157     100
# 160     108
# 162     141
# 167     150
# 168     303
# 169     268
# 170     287
# 171     150
# 172     153
# 175     245
# 182     159
# 184     137
# Name: Pulse, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df)
df.groupby('Calories')['Duration'].sum()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# Calories
# 50.3       20
# 50.5       15
# 77.7       20
# 86.2       30
# 92.7       30
#          ...
# 1115.0    150
# 1376.0    210
# 1500.2    300
# 1729.0    270
# 1860.4    210
# Name: Duration, Length: 142, dtype: int64

# %%
## To drop the specified row/column :- use Drop("xxxx",axis='xxxx') attribute.
df.drop('Calories',axis = 'columns')
# Out:
#      Duration  Pulse  Maxpulse
# 0          60    110       130
# 1          60    117       145
# 2          60    103       135
# 3          45    109       175
# 4          45    117       148
# ..        ...    ...       ...
# 164        60    105       140
# 165        60    110       145
# 166        60    115       145
# 167        75    120       150
# 168        75    125       150
#
# [169 rows x 3 columns]

# %%
## To drop all the rows that contain null values :- use dropna()
df.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
## To Get the values of a group of elements in the specified positions:- use iloc[] attribute.
df.iloc[168]
# Out:
# Duration     75.0
# Pulse       125.0
# Maxpulse    150.0
# Calories    330.4
# Name: 168, dtype: float64

# %%
df.iloc[40:129]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 40         45     90       112     180.1
# 41         60     98       126     286.0
# 42         60    100       122     329.4
# 43         60    111       138     400.0
# 44         60    111       131     397.0
# ..        ...    ...       ...       ...
# 124        60    111       151     368.5
# 125        60     98       122     271.0
# 126        60     97       124     275.3
# 127        60    109       127     382.0
# 128        90     99       125     466.4
#
# [89 rows x 4 columns]

# %%
df.iloc[40:129][["Pulse","Maxpulse"]]
# Out:
#      Pulse  Maxpulse
# 40      90       112
# 41      98       126
# 42     100       122
# 43     111       138
# 44     111       131
# ..     ...       ...
# 124    111       151
# 125     98       122
# 126     97       124
# 127    109       127
# 128     99       125
#
# [89 rows x 2 columns]

# %%
df.iloc[80:161][["Duration","Calories"]]
# Out:
#      Duration  Calories
# 80         30     319.2
# 81         45     344.0
# 82         30     151.1
# 83        120     500.0
# 84         45     225.3
# ..        ...       ...
# 156        60     270.4
# 157        60     270.4
# 158        60     382.8
# 159        30     240.9
# 160        30     250.4
#
# [81 rows x 2 columns]

# %%
df.loc[df.Pulse==100]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 11         60    100       120     250.7
# 16         60    100       120     300.0
# 21         45    100       119     282.0
# 25         60    100       120     250.0
# 28         60    100       132     280.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 42         60    100       122     329.4
# 72         90    100       127     700.0
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 83        120    100       130     500.0
# 84         45    100       120     225.3
# 87        120    100       157    1000.1
# 113        45    100       120     225.3
# 121        45    100       120     100.7
# 142        45    100       120     250.4
# 157        60    100       120     270.4
# 163        45    100       140     280.9

# %%
df.max()
# Out:
# Duration     300.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64

# %%
df.min()
# Out:
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64

# %% [markdown]
# ####Plotting of calories Dataset

# %%
## Plotting:-
import matplotlib.pyplot as plt
df.plot()
# Out:
# <Axes: >

# %%
## Plot bar graph
df.plot(kind='bar',y = 'Pulse',x = 'Duration')
# Out:
# <Axes: xlabel='Duration'>

# %%
## Plot Pie chart
import pandas as pd
df = pd.read_csv('data.csv')
df.plot(kind='pie',y='Calories')
# Out:
# <Axes: ylabel='Calories'>

# %%
## Plot with groupby
df.groupby('Maxpulse')['Calories'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='Calories'>

# %%
df.groupby('Pulse')['Duration'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='Duration'>

# %%
## Plot histogram graph:-
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
## Plot density graph:-
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
## Plot density graph with groupby:-
df.groupby(['Duration'][['Pulse','Maxpulse']]).plot(kind='density')

# %%
## Plot scatter graph
df.plot(kind='scatter',x= 'Duration',y='Calories')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
## PLot area graph.
df.plot(kind='area')
# Out:
# <Axes: >

# %%
df.groupby('Duration')['Calories'].plot(kind='area')
# Out:
# Duration
# 15     Axes(0.125,0.11;0.775x0.77)
# 20     Axes(0.125,0.11;0.775x0.77)
# 25     Axes(0.125,0.11;0.775x0.77)
# 30     Axes(0.125,0.11;0.775x0.77)
# 45     Axes(0.125,0.11;0.775x0.77)
# 60     Axes(0.125,0.11;0.775x0.77)
# 75     Axes(0.125,0.11;0.775x0.77)
# 80     Axes(0.125,0.11;0.775x0.77)
# 90     Axes(0.125,0.11;0.775x0.77)
# 120    Axes(0.125,0.11;0.775x0.77)
# 150    Axes(0.125,0.11;0.775x0.77)
# 160    Axes(0.125,0.11;0.775x0.77)
# 180    Axes(0.125,0.11;0.775x0.77)
# 210    Axes(0.125,0.11;0.775x0.77)
# 270    Axes(0.125,0.11;0.775x0.77)
# 300    Axes(0.125,0.11;0.775x0.77)
# Name: Calories, dtype: object

# %%
df.groupby('Maxpulse')['Pulse'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Maxpulse'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.groupby('Maxpulse')['Pulse'].count().plot(kind='box')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df.hist()
plt.show()

# %% [markdown]
# ###Plotting with Seaborn - calories dataset

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.set_style("whitegrid")
sns.pairplot(df)

# %%
sns.pairplot(df, hue="Pulse", palette="husl", size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, hue="Calories", palette="husl", size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_theme(style="ticks")
sns.pairplot(df,hue = 'Calories')
