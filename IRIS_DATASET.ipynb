# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("Iris.csv")

# %%
print(df1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(df1.to_string())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0      1            5.1           3.5            1.4           0.2      Iris-setosa
# 1      2            4.9           3.0            1.4           0.2      Iris-setosa
# 2      3            4.7           3.2            1.3           0.2      Iris-setosa
# 3      4            4.6           3.1            1.5           0.2      Iris-setosa
# 4      5            5.0           3.6            1.4           0.2      Iris-setosa
# 5      6            5.4           3.9            1.7           0.4      Iris-setosa
# 6      7            4.6           3.4            1.4           0.3      Iris-setosa
# 7      8            5.0           3.4            1.5           0.2      Iris-setosa
# 8      9            4.4           2.9            1.4           0.2      Iris-setosa
# 9     10            4.9           3.1            1.5           0.1      Iris-setosa
# ...

# %%
df1.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1.head(20)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df1.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df1.tail(30)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# ...

# %%
df1.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df1['SepalWidthCm']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
df1['PetalLengthCm']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
df1[['SepalLengthCm','PetalWidthCm']]
# Out:
#      SepalLengthCm  PetalWidthCm
# 0              5.1           0.2
# 1              4.9           0.2
# 2              4.7           0.2
# 3              4.6           0.2
# 4              5.0           0.2
# ..             ...           ...
# 145            6.7           2.3
# 146            6.3           1.9
# 147            6.5           2.0
# 148            6.2           2.3
# 149            5.9           1.8
#
# [150 rows x 2 columns]

# %%
df1[['PetalLengthCm','Species']]
# Out:
#      PetalLengthCm         Species
# 0              1.4     Iris-setosa
# 1              1.4     Iris-setosa
# 2              1.3     Iris-setosa
# 3              1.5     Iris-setosa
# 4              1.4     Iris-setosa
# ..             ...             ...
# 145            5.2  Iris-virginica
# 146            5.0  Iris-virginica
# 147            5.2  Iris-virginica
# 148            5.4  Iris-virginica
# 149            5.1  Iris-virginica
#
# [150 rows x 2 columns]

# %%
df1[['PetalLengthCm','SepalLengthCm']]
# Out:
#      PetalLengthCm  SepalLengthCm
# 0              1.4            5.1
# 1              1.4            4.9
# 2              1.3            4.7
# 3              1.5            4.6
# 4              1.4            5.0
# ..             ...            ...
# 145            5.2            6.7
# 146            5.0            6.3
# 147            5.2            6.5
# 148            5.4            6.2
# 149            5.1            5.9
#
# [150 rows x 2 columns]

# %%
df1["PetalLengthCm"].mean()
# Out:
# 3.758666666666666

# %%
df1["SepalWidthCm"].median()
# Out:
# 3.0

# %%
df1.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df1.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %%
df1.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df1.iloc[29:148]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 29    30            4.7           3.2            1.6           0.2
# 30    31            4.8           3.1            1.6           0.2
# 31    32            5.4           3.4            1.5           0.4
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
#
#             Species
# 29      Iris-setosa
# 30      Iris-setosa
# 31      Iris-setosa
# 32      Iris-setosa
# 33      Iris-setosa
# ..              ...
# ...

# %%
df1.iloc[88]
# Out:
# Id                            89
# SepalLengthCm                5.6
# SepalWidthCm                 3.0
# PetalLengthCm                4.1
# PetalWidthCm                 1.3
# Species          Iris-versicolor
# Name: 88, dtype: object

# %%
df1.iloc[45:99, :4][['SepalLengthCm','SepalWidthCm']]
# Out:
#     SepalLengthCm  SepalWidthCm
# 45            4.8           3.0
# 46            5.1           3.8
# 47            4.6           3.2
# 48            5.3           3.7
# 49            5.0           3.3
# 50            7.0           3.2
# 51            6.4           3.2
# 52            6.9           3.1
# 53            5.5           2.3
# 54            6.5           2.8
# 55            5.7           2.8
# 56            6.3           3.3
# 57            4.9           2.4
# 58            6.6           2.9
# 59            5.2           2.7
# 60            5.0           2.0
# 61            5.9           3.0
# 62            6.0           2.2
# 63            6.1           2.9
# 64            5.6           2.9
# 65            6.7           3.1
# 66            5.6           3.0
# 67            5.8           2.7
# 68            6.2           2.2
# 69            5.6           2.5
# 70            5.9           3.2
# 71            6.1           2.8
# 72            6.3           2.5
# ...

# %%
df1.iloc[31:61][['PetalLengthCm','PetalWidthCm']]
# Out:
#     PetalLengthCm  PetalWidthCm
# 31            1.5           0.4
# 32            1.5           0.1
# 33            1.4           0.2
# 34            1.5           0.1
# 35            1.2           0.2
# 36            1.3           0.2
# 37            1.5           0.1
# 38            1.3           0.2
# 39            1.5           0.2
# 40            1.3           0.3
# 41            1.3           0.3
# 42            1.3           0.2
# 43            1.6           0.6
# 44            1.9           0.4
# 45            1.4           0.3
# 46            1.6           0.2
# 47            1.4           0.2
# 48            1.5           0.2
# 49            1.4           0.2
# 50            4.7           1.4
# 51            4.5           1.5
# 52            4.9           1.5
# 53            4.0           1.3
# 54            4.6           1.5
# 55            4.5           1.3
# 56            4.7           1.6
# 57            3.3           1.0
# 58            4.6           1.3
# ...

# %%
df1.iloc[56:66] [['PetalLengthCm','SepalWidthCm']]
# Out:
#     PetalLengthCm  SepalWidthCm
# 56            4.7           3.3
# 57            3.3           2.4
# 58            4.6           2.9
# 59            3.9           2.7
# 60            3.5           2.0
# 61            4.2           3.0
# 62            4.0           2.2
# 63            4.7           2.9
# 64            3.6           2.9
# 65            4.4           3.1

# %%
df1.loc[df1['SepalLengthCm'] >4] [ 'SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df3 = df1.loc[df1['PetalLengthCm']>1] [df1['SepalLengthCm']>4]
df3[["PetalLengthCm","SepalLengthCm"]]
# Out:
# <ipython-input-34-5d4276a2d7ce>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = df1.loc[df1['PetalLengthCm']>1] [df1['SepalLengthCm']>4]
#      PetalLengthCm  SepalLengthCm
# 0              1.4            5.1
# 1              1.4            4.9
# 2              1.3            4.7
# 3              1.5            4.6
# 4              1.4            5.0
# ..             ...            ...
# 145            5.2            6.7
# 146            5.0            6.3
# 147            5.2            6.5
# 148            5.4            6.2
# 149            5.1            5.9
#
# [149 rows x 2 columns]

# %%
df1.loc[df1['PetalLengthCm']>3] ['PetalLengthCm']
# Out:
# 50     4.7
# 51     4.5
# 52     4.9
# 53     4.0
# 54     4.6
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 99, dtype: float64

# %%
df1.groupby('SepalLengthCm')['SepalWidthCm'].count()
# Out:
# SepalLengthCm
# 4.3     1
# 4.4     3
# 4.5     1
# 4.6     4
# 4.7     2
# 4.8     5
# 4.9     6
# 5.0    10
# 5.1     9
# 5.2     4
# 5.3     1
# 5.4     6
# 5.5     7
# 5.6     6
# 5.7     8
# 5.8     7
# 5.9     3
# 6.0     6
# 6.1     6
# 6.2     4
# 6.3     9
# 6.4     7
# 6.5     5
# 6.6     2
# 6.7     8
# 6.8     3
# 6.9     4
# 7.0     1
# 7.1     1
# 7.2     3
# 7.3     1
# 7.4     1
# 7.6     1
# 7.7     4
# 7.9     1
# Name: SepalWidthCm, dtype: int64

# %%
df1.groupby('SepalLengthCm')['PetalLengthCm'].mean()
# Out:
# SepalLengthCm
# 4.3    1.100000
# 4.4    1.333333
# 4.5    1.300000
# 4.6    1.325000
# 4.7    1.450000
# 4.8    1.580000
# 4.9    2.283333
# 5.0    1.840000
# 5.1    1.722222
# 5.2    2.075000
# 5.3    1.500000
# 5.4    2.033333
# 5.5    3.228571
# 5.6    4.200000
# 5.7    3.587500
# 5.8    4.071429
# 5.9    4.700000
# 6.0    4.650000
# 6.1    4.750000
# 6.2    4.750000
# 6.3    5.133333
# 6.4    5.157143
# 6.5    5.240000
# 6.6    4.500000
# 6.7    5.262500
# 6.8    5.400000
# 6.9    5.275000
# 7.0    4.700000
# 7.1    5.900000
# 7.2    5.966667
# 7.3    6.300000
# 7.4    6.100000
# 7.6    6.600000
# 7.7    6.600000
# 7.9    6.400000
# Name: PetalLengthCm, dtype: float64

# %%
df1.groupby('SepalWidthCm')['PetalLengthCm'].mean()
# Out:
# SepalWidthCm
# 2.0    3.500000
# 2.2    4.500000
# 2.3    3.250000
# 2.4    3.600000
# 2.5    4.512500
# 2.6    4.880000
# 2.7    4.622222
# 2.8    5.042857
# 2.9    4.350000
# 3.0    4.234615
# 3.1    3.600000
# 3.2    3.753846
# 3.3    4.200000
# 3.4    2.466667
# 3.5    1.416667
# 3.6    2.833333
# 3.7    1.500000
# 3.8    3.300000
# 3.9    1.500000
# 4.0    1.200000
# 4.1    1.500000
# 4.2    1.400000
# 4.4    1.500000
# Name: PetalLengthCm, dtype: float64

# %%
df1.loc[:,'Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.plot(kind='pie',y='PetalLengthCm')
# Out:
# <Axes: ylabel='PetalLengthCm'>

# %%
df1.plot(kind='area')
# Out:
# <Axes: >

# %%
df1.plot(kind='box')
# Out:
# <Axes: >

# %%
df1.groupby('PetalLengthCm')["PetalWidthCm"].plot()
# Out:
# PetalLengthCm
# 1.0    Axes(0.125,0.11;0.775x0.77)
# 1.1    Axes(0.125,0.11;0.775x0.77)
# 1.2    Axes(0.125,0.11;0.775x0.77)
# 1.3    Axes(0.125,0.11;0.775x0.77)
# 1.4    Axes(0.125,0.11;0.775x0.77)
# 1.5    Axes(0.125,0.11;0.775x0.77)
# 1.6    Axes(0.125,0.11;0.775x0.77)
# 1.7    Axes(0.125,0.11;0.775x0.77)
# 1.9    Axes(0.125,0.11;0.775x0.77)
# 3.0    Axes(0.125,0.11;0.775x0.77)
# 3.3    Axes(0.125,0.11;0.775x0.77)
# 3.5    Axes(0.125,0.11;0.775x0.77)
# 3.6    Axes(0.125,0.11;0.775x0.77)
# 3.7    Axes(0.125,0.11;0.775x0.77)
# 3.8    Axes(0.125,0.11;0.775x0.77)
# 3.9    Axes(0.125,0.11;0.775x0.77)
# 4.0    Axes(0.125,0.11;0.775x0.77)
# 4.1    Axes(0.125,0.11;0.775x0.77)
# 4.2    Axes(0.125,0.11;0.775x0.77)
# 4.3    Axes(0.125,0.11;0.775x0.77)
# 4.4    Axes(0.125,0.11;0.775x0.77)
# 4.5    Axes(0.125,0.11;0.775x0.77)
# 4.6    Axes(0.125,0.11;0.775x0.77)
# 4.7    Axes(0.125,0.11;0.775x0.77)
# 4.8    Axes(0.125,0.11;0.775x0.77)
# 4.9    Axes(0.125,0.11;0.775x0.77)
# ...

# %%
df1.groupby('SepalLengthCm')['PetalLengthCm'].count().plot(kind='line')
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
df1.groupby('PetalLengthCm')['SepalWidthCm'].mean().plot(kind='area')
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %%
df1.groupby('PetalLengthCm')['SepalWidthCm'].median().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.groupby('PetalWidthCm')['SepalWidthCm'].plot(kind='pie')
# Out:
# PetalWidthCm
# 0.1    Axes(0.22375,0.11;0.5775x0.77)
# 0.2    Axes(0.22375,0.11;0.5775x0.77)
# 0.3    Axes(0.22375,0.11;0.5775x0.77)
# 0.4    Axes(0.22375,0.11;0.5775x0.77)
# 0.5    Axes(0.22375,0.11;0.5775x0.77)
# 0.6    Axes(0.22375,0.11;0.5775x0.77)
# 1.0    Axes(0.22375,0.11;0.5775x0.77)
# 1.1    Axes(0.22375,0.11;0.5775x0.77)
# 1.2    Axes(0.22375,0.11;0.5775x0.77)
# 1.3    Axes(0.22375,0.11;0.5775x0.77)
# 1.4    Axes(0.22375,0.11;0.5775x0.77)
# 1.5    Axes(0.22375,0.11;0.5775x0.77)
# 1.6    Axes(0.22375,0.11;0.5775x0.77)
# 1.7    Axes(0.22375,0.11;0.5775x0.77)
# 1.8    Axes(0.22375,0.11;0.5775x0.77)
# 1.9    Axes(0.22375,0.11;0.5775x0.77)
# 2.0    Axes(0.22375,0.11;0.5775x0.77)
# 2.1    Axes(0.22375,0.11;0.5775x0.77)
# 2.2    Axes(0.22375,0.11;0.5775x0.77)
# 2.3    Axes(0.22375,0.11;0.5775x0.77)
# 2.4    Axes(0.22375,0.11;0.5775x0.77)
# 2.5    Axes(0.22375,0.11;0.5775x0.77)
# Name: SepalWidthCm, dtype: object

# %%
df1.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
df1.hist()
plt.show()

# %% [markdown]
# ### PLOTTING with Seaborn

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.set_style("whitegrid")
sns.pairplot(df1)

# %%
sns.pairplot(df1, hue="Species", palette="husl", size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_theme(style="ticks")
sns.pairplot(df1,hue = 'Species')

# %% [markdown]
# #### MACHINE LEARNING

# %%
import pandas as pd
pd.read_csv=("Iris.csv")
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df1 = df1.values
print(df1.shape)
# Out:
# (150, 6)

# %%
#divide data into feature matrix and target matrix
X = df1[:,:5] # all the rows and first four columns 0-3
Y = df1[:,5]   # all the rows and only fourth column (last column )
print(X.shape, Y.shape)
# Out:
# (150, 5) (150,)

# %%
print(X)
# Out:
# [[1 5.1 3.5 1.4 0.2]
#  [2 4.9 3.0 1.4 0.2]
#  [3 4.7 3.2 1.3 0.2]
#  [4 4.6 3.1 1.5 0.2]
#  [5 5.0 3.6 1.4 0.2]
#  [6 5.4 3.9 1.7 0.4]
#  [7 4.6 3.4 1.4 0.3]
#  [8 5.0 3.4 1.5 0.2]
#  [9 4.4 2.9 1.4 0.2]
#  [10 4.9 3.1 1.5 0.1]
#  [11 5.4 3.7 1.5 0.2]
#  [12 4.8 3.4 1.6 0.2]
#  [13 4.8 3.0 1.4 0.1]
#  [14 4.3 3.0 1.1 0.1]
#  [15 5.8 4.0 1.2 0.2]
#  [16 5.7 4.4 1.5 0.4]
#  [17 5.4 3.9 1.3 0.4]
#  [18 5.1 3.5 1.4 0.3]
#  [19 5.7 3.8 1.7 0.3]
#  [20 5.1 3.8 1.5 0.3]
#  [21 5.4 3.4 1.7 0.2]
#  [22 5.1 3.7 1.5 0.4]
#  [23 4.6 3.6 1.0 0.2]
#  [24 5.1 3.3 1.7 0.5]
#  [25 4.8 3.4 1.9 0.2]
#  [26 5.0 3.0 1.6 0.2]
#  [27 5.0 3.4 1.6 0.4]
#  [28 5.2 3.5 1.5 0.2]
#  [29 5.2 3.4 1.4 0.2]
#  [30 4.7 3.2 1.6 0.2]
#  [31 4.8 3.1 1.6 0.2]
#  [32 5.4 3.4 1.5 0.4]
#  [33 5.2 4.1 1.5 0.1]
#  [34 5.5 4.2 1.4 0.2]
#  [35 4.9 3.1 1.5 0.1]
#  [36 5.0 3.2 1.2 0.2]
#  [37 5.5 3.5 1.3 0.2]
#  [38 4.9 3.1 1.5 0.1]
#  [39 4.4 3.0 1.3 0.2]
#  [40 5.1 3.4 1.5 0.2]
#  [41 5.0 3.5 1.3 0.3]
#  [42 4.5 2.3 1.3 0.3]
# ...

# %%
print(Y)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...

# %%
df1[:,5]
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
#fit this in model
from sklearn.linear_model import LogisticRegression
model1= LogisticRegression()

# %%
model1.fit(X,Y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model1.predict([[ 1,5.1,3.5,1.4,0.2 ]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model1.predict ([[2,2.9,3.0,3.1,1.8]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model1.predict([[148 ,6.5,	3.0,	5.2,	2.0]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
model1.predict([[146 ,6.7, 3.0 , 5.2, 2.3]])
# Out:
# array(['Iris-virginica'], dtype=object)
